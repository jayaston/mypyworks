# %%
#正式开始
import json
import pandas as pd
import numpy as np
from pyecharts.charts import BMap, Timeline, Tab
from pyecharts import options as opts
from pyecharts.commons.utils import JsCode
from pyecharts.globals import BMapType, ChartType
import os
import re
import configparser

from urllib.request import urlopen, quote
import requests
def getlnglat(address):
    url = 'http://api.map.baidu.com/geocoder/v2/'
    output = 'json'
    ak = 'EoDE9x4kPxLNCtUMxfGEYlvG9inVGaUr' # 百度地图ak，具体申请自行百度，提醒需要在“控制台”-“设置”-“启动服务”-“正逆地理编码”，启动
    address = quote(address) # 由于本文地址变量为中文，为防止乱码，先用quote进行编码
    uri = url + '?' + 'address=' + address  + '&output=' + output + '&ak=' + ak 
    req = urlopen(uri)
    res = req.read().decode() 
    temp = json.loads(res)
    lat = temp['result']['location']['lat']
    lng = temp['result']['location']['lng']
    return [lng,lat]   # 纬度 latitude   ，   经度 longitude  ，

# %%
configPath_district = r"c:\Users\xiejie\mypyworks\loc_district.ini"
conf_district = configparser.ConfigParser()
conf_district.read(configPath_district,encoding="utf-8-sig")
# Out:
# ['c:\\Users\\xiejie\\mypyworks\\loc_district.ini']

# %%
configPath_zone1 = r"c:\Users\xiejie\mypyworks\loc_zone1.ini"
conf_zone1 = configparser.ConfigParser()
conf_zone1.read(configPath_zone1,encoding="utf-8-sig")
# Out:
# ['c:\\Users\\xiejie\\mypyworks\\loc_zone1.ini']

# %%
configPath_zone2 = r"c:\Users\xiejie\mypyworks\loc_zone2.ini"
conf_zone2 = configparser.ConfigParser()
conf_zone2.read(configPath_zone2,encoding="utf-8-sig")
# Out:
# ['c:\\Users\\xiejie\\mypyworks\\loc_zone2.ini']

# %%
configPath_zone3 = r"c:\Users\xiejie\mypyworks\loc_zone3.ini"
conf_zone3 = configparser.ConfigParser()
conf_zone3.read(configPath_zone3,encoding="utf-8-sig")
# Out:
# ['c:\\Users\\xiejie\\mypyworks\\loc_zone3.ini']

# %%
#输入增加的水厂
#res = []
# address = ['杨箕地铁站','广东省博物馆']
# for i in address:
#     geo_coord = getlnglat(i)
#     #geo_coord.append(2)
#     res.append([i, geo_coord])
#手动输入水厂中心点坐标
res_shuichang = [['西村水厂',[113.242737,23.146652],100],
                 ['石门水厂',[113.217581,23.199655],80],
                 ['江村水厂',[113.268646,23.283703],45],                 
                 ['北部水厂',[113.201437,23.218786],60],
                 ['南州水厂',[113.336227,23.06211],100],
                 ['新塘水厂',[113.675056,23.135007],70],
                 ['西洲水厂',[113.593658,23.103533],50],
                ]
#输入二级分区中心点
res_zone2 = [[i,float(conf_zone2.get(i,"center").split(',')[0])+0.0065,float(conf_zone2.get(i,"center").split(',')[1])+0.0059] for i in conf_zone2.sections()]
#输入三级分区
#res_zone3 = [[i,float(conf_zone3.get(i,"center").split(',')[0])+0.0065,float(conf_zone3.get(i,"center").split(',')[1])+0.0059] for i in conf_zone3.sections()]

# %%
chanxiaocha = pd.read_excel(r'd:\专题工作（重要）\产销差工作\产销差数据与资料积累\产销差分析周月报图表.xlsx',
                      sheet_name=15,header=[0,1])

# %%
tl_leijizaice = Timeline(init_opts=opts.InitOpts(width="1200px", height="800px")).add_schema(
    is_auto_play= True, pos_bottom="25px",
    label_opts=opts.LabelOpts(rotate=0,font_size= 14,font_weight='bold'),
    )


for yue in ['2021年1月','2021年2月','2021年3月','2021年4月','2021年5月','2021年6月','2021年7月']:    
    gongshuiliang = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('本期','供水量')][:34])
    zaiceshuiliang = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('本期','在册售水量')][:34])
    shoushuiliang = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('本期','售水量')][:34])
    zaice = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('本期','在册产销差')][:34])
    zonghe = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('本期','综合产销差')][:34])

    gongshuiliangtongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('同比','供水量')][:34])
    zaiceshuiliangtongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('同比','在册售水量')][:34])
    shoushuiliangtongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('同比','售水量')][:34])
    zaicetongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('同比','在册产销差')][:34])
    zonghetongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('同比','综合产销差')][:34])

    gongshuilianghuanbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('环比','供水量')][:34])
    zaiceshuilianghuanbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('环比','在册售水量')][:34])
    shoushuilianghuanbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('环比','售水量')][:34])
    zaicehuanbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('环比','在册产销差')][:34])
    zonghehuanbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('环比','综合产销差')][:34])

    gongshuiliangleiji = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计','供水量')][:34])
    zaiceshuiliangleiji = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计','在册售水量')][:34])
    shoushuiliangleiji = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计','售水量')][:34])
    zaiceleiji = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计','在册产销差')][:34])
    zongheleiji = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计','综合产销差')][:34])

    gongshuiliangleijitongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计同比','供水量')][:34])
    zaiceshuiliangleijitongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计同比','在册售水量')][:34])
    shoushuiliangleijitongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计同比','售水量')][:34])
    zaiceleijitongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计同比','在册产销差')][:34])
    zongheleijitongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计同比','综合产销差')][:34])


    zaiceleijihuanbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计环比','在册产销差')][:34])
    zongheleijihuanbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计环比','综合产销差')][:34])    
    
    c = BMap(init_opts=opts.InitOpts(width="1200px", height="800px")
            ).add_schema(
            baidu_ak="EoDE9x4kPxLNCtUMxfGEYlvG9inVGaUr",
            center=[113.398609,23.174159],
            zoom=12,
            is_roam=True,#是否支持缩放

        ).set_global_opts(
            title_opts=opts.TitleOpts(
                title="二级分区累计在册产销差率同比变化热力图",
                #subtitle="data from PM25.in",
                #subtitle_link="http://www.pm25.in",
                pos_left="center",
                title_textstyle_opts=opts.TextStyleOpts(color="#000"),
            ),
    #         toolbox_opts=opts.ToolboxOpts(
    #                      feature = opts.ToolBoxFeatureOpts(
    #                      save_as_image = opts.ToolBoxFeatureSaveAsImageOpts('jpeg'),),
    #                      ),
            visualmap_opts=opts.VisualMapOpts(min_= -50,max_= 50,
                                              pos_right= '0%',pos_top= '5%',
                                              range_color=["lightskyblue","grey", "orangered"],
                                              is_piecewise =True,
                                              pieces = [{"min": 50, "color": '#E64A19'},                                                 
                                                        {"min": 30, "max": 50, "color": '#FF5722'},
                                                        {"min": 10, "max": 30, "color": '#FF8A65'},
                                                        {"min": 0, "max": 10, "color": '#FFCCBC'},
                                                        {"min": -10, "max": 0, "color": '#B3E5FC'},
                                                        {"min": -30, "max": -10, "color": '#4FC3F7'},
                                                        {"min": -50, "max": -30, "color": '#03A9F4'},
                                                        {"max": -50, "color": '#0288D1'}
                                                        ] ,
                                              precision=0,
                                              series_index=1,
                                              dimension = 28,#设置哪个指标显示热力图
                                              range_text = ['在册产销差同比高', '在册产销差同比低'],
                                              textstyle_opts = opts.TextStyleOpts(color = "#B71C1C",font_weight='bolder')
                                             ),
            legend_opts=opts.LegendOpts(is_show=False),
            tooltip_opts=opts.TooltipOpts(trigger="item",formatter=JsCode(  
                                                    """function(params) {
                                                     str = params.data.name+'<br/>'
    +'累计在册产销差：'+ (params.data.value[8]*100).toFixed(2)+'%；同比：'+params.data.value[28].toFixed(2)+'%；环比：'+params.data.value[11].toFixed(2)+'%<br/>'
    +'累计综合产销差：'+ (params.data.value[9]*100).toFixed(2)+'%；同比：'+params.data.value[10].toFixed(2)+'%；环比：'+params.data.value[12].toFixed(2)+'%<br/>'
    +'当月在册产销差：'+(params.data.value[2]*100).toFixed(2)+'%；同比：'+params.data.value[4].toFixed(2)+'%；环比：'+params.data.value[6].toFixed(2)+'%<br/>'
    +'当月综合产销差：'+ (params.data.value[3]*100).toFixed(2)+'%；同比：'+params.data.value[5].toFixed(2)+'%；环比：'+params.data.value[7].toFixed(2)+'%<br/>'
    +'当月供水量：  '+ (params.data.value[13]).toFixed(0)+'万；同比：'+params.data.value[14].toFixed(2)+'%；环比：'+params.data.value[15].toFixed(2)+'%<br/>'
    +'当月在册水量：'+ (params.data.value[16]).toFixed(0)+'万；同比：'+params.data.value[17].toFixed(2)+'%；环比：'+params.data.value[18].toFixed(2)+'%<br/>'
    +'当月售水量：  '+ (params.data.value[19]).toFixed(0)+'万；同比：'+params.data.value[20].toFixed(2)+'%；环比：'+params.data.value[21].toFixed(2)+'%<br/>'
    +'累计供水量：  '+ (params.data.value[22]).toFixed(0)+'万；同比：'+params.data.value[23].toFixed(2)+'%<br/>'
    +'累计在册水量：'+ (params.data.value[24]).toFixed(0)+'万；同比：'+params.data.value[25].toFixed(2)+'%<br/>'
    +'累计售水量：  '+ (params.data.value[26]).toFixed(0)+'万；同比：'+params.data.value[27].toFixed(2)+'%<br/>';
                                                     return str }
                                                """ )
                                         ,textstyle_opts = opts.TextStyleOpts(font_size=14)),
        ).add_control_panel(
            copyright_control_opts=opts.BMapCopyrightTypeOpts(position=2, copyright_= "",offset_height = 100,),
            maptype_control_opts=opts.BMapTypeControlOpts(
                type_=BMapType.MAPTYPE_CONTROL_DROPDOWN
            ),
            scale_control_opts=opts.BMapScaleControlOpts(),
            overview_map_opts=opts.BMapOverviewMapControlOpts(is_open=False),
            navigation_control_opts=opts.BMapNavigationControlOpts(is_enable_geo_location= False),
            geo_location_control_opts=opts.BMapGeoLocationControlOpts(),
        )

    #增加一级分区数据项
    data_zone1= []
    for i in conf_zone1.sections():
        #c.add_coordinate(i[0],i[1],i[2])
        loc = conf_zone1.get(i,"loc")
        loc = [[float(y[0])+0.0065,float(y[1])+0.0059] for y in [x.split(' ') for x in loc.split(',')]]
        loc0 = loc[0]
        loc.append(loc0)
        data_zone1.append(loc)

    #增加二级分区中心点和数据项
    data_zone2= []
    """
    当月在册j1 同比j3 环比j5
    当月综合j2 同比j4 环比j6
    累计在册j7 同比j9 环比j11
    累计综合j8 同比j10 环比j12
    当月供水j13  同比j14 环比j15
    当月在册售水j16  同比j17 环比j18
    当月售水j19,同比j20,环比j21
    累计供水j22,同比j23
    累计在册售水j24,j25,
    累计售水量j26,j27
    """
    for i,j1,j2,j3,j4,j5,j6,j7,j8,j9,j10,j11,j12,j13,j14,j15,j16,j17,j18,j19,j20,j21,j22,j23,j24,j25,j26,j27 in zip(
        res_zone2,zaice,zonghe,zaicetongbi,zonghetongbi,zaicehuanbi,zonghehuanbi,
        zaiceleiji,zongheleiji,zaiceleijitongbi,zongheleijitongbi,zaiceleijihuanbi,zongheleijihuanbi,
        gongshuiliang,gongshuiliangtongbi,gongshuilianghuanbi,
        zaiceshuiliang,zaiceshuiliangtongbi,zaiceshuilianghuanbi,
        shoushuiliang,shoushuiliangtongbi,shoushuilianghuanbi,
        gongshuiliangleiji,gongshuiliangleijitongbi,
        zaiceshuiliangleiji,zaiceshuiliangleijitongbi,
        shoushuiliangleiji,shoushuiliangleijitongbi):
        c.add_coordinate(i[0],i[1],i[2])
        loc = conf_zone2.get(i[0],"loc")
        loc = [[float(y[0])+0.0065,float(y[1])+0.0059] for y in [x.split(' ') for x in loc.split(',')]]
        data_zone2.append(opts.MapItem(name=i[0],value=[re.findall(r"^\S+\d+",i[0])[0],str(loc),j1,j2,j3,j4,j5,j6,j7,j8,j10,j11,j12,j13,j14,j15,j16,j17,j18,j19,j20,j21,j22,j23,j24,j25,j26,j27,j9]))

    #增加三级分区数据项
    data_zone3= []
    for i in conf_zone3.sections():
        #c.add_coordinate(i[0],i[1],i[2])
        loc = conf_zone3.get(i,"loc")
        loc = [[float(y[0])+0.0065,float(y[1])+0.0059] for y in [x.split(' ') for x in loc.split(',')]]
        data_zone3.append(opts.MapItem(name=i,value=[re.findall(r"(?<=\)).+$",i)[0],str(loc),0]))

    #增加热力图
    # c.add(  "产销差率",
    #         data_zone2,
    #         type_="heatmap",
    #         label_opts=opts.LabelOpts(formatter="{b}"),
    #     )

    #增加水厂点
    data = []
    for i in res_shuichang:
        c.add_coordinate(i[0],i[1][0],i[1][1])
        data.append([i[0],i[2]])

    #画水厂
    c.add(type_="effectScatter",
            series_name="水厂",
            data_pair=data,
            symbol_size=8,
            effect_opts=opts.EffectOpts(),
            label_opts=opts.LabelOpts(formatter="{b}", position="right", is_show=True),
            itemstyle_opts=opts.ItemStyleOpts(color="purple"),)

    #画二级分区
    c.add(series_name='二级分区',       
        type_=ChartType.CUSTOM,
        render_item=JsCode("""
        function renderItem(params, api) {
            var coords = eval(api.value(1));
            var points = [];
            for (var i = 0; i < coords.length; i++) {
                points.push(api.coord(coords[i]));
            }
            var color = api.visual('color');

            return {
                type: 'polygon',
                shape: {
                    points: new echarts.graphic.clipPointsByRect(points, {
                        x: params.coordSys.x,
                        y: params.coordSys.y,
                        width: params.coordSys.width,
                        height: params.coordSys.height
                    })
                },
                style: api.style({
                    fill: color,
                    z: 2,            
                    opacity:0.6,                
                    lineWidth: 1,
                    textAlign: 'center',
                    textVerticalAlign:'bottom',
                    stroke: new echarts.color.lift(color)                   
                }),
                styleEmphasis: api.styleEmphasis()
            };
        }

            """),        
        data_pair = data_zone2
         )

    #画一级分区
    c.add(series_name='一级分区',
          type_="lines",
          data_pair = data_zone1,
          is_polyline=True,       
          linestyle_opts=opts.LineStyleOpts(color="#fff", opacity=1, width=2,type_='dashed'),
          effect_opts=opts.EffectOpts(is_show = False),       
         )
    tl_leijizaice.add(c, "{}".format(yue))
#tl.render("二级分区累计在册产销差月度变化.html")

# %%
tl_leijizonghe = Timeline(init_opts=opts.InitOpts(width="1200px", height="800px")).add_schema(
    is_auto_play= True, pos_bottom="25px",
    label_opts=opts.LabelOpts(rotate=0,font_size= 14,font_weight='bold'),
    )


for yue in ['2021年1月','2021年2月','2021年3月','2021年4月','2021年5月','2021年6月','2021年7月']:    
    gongshuiliang = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('本期','供水量')][:34])
    zaiceshuiliang = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('本期','在册售水量')][:34])
    shoushuiliang = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('本期','售水量')][:34])
    zaice = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('本期','在册产销差')][:34])
    zonghe = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('本期','综合产销差')][:34])

    gongshuiliangtongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('同比','供水量')][:34])
    zaiceshuiliangtongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('同比','在册售水量')][:34])
    shoushuiliangtongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('同比','售水量')][:34])
    zaicetongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('同比','在册产销差')][:34])
    zonghetongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('同比','综合产销差')][:34])

    gongshuilianghuanbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('环比','供水量')][:34])
    zaiceshuilianghuanbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('环比','在册售水量')][:34])
    shoushuilianghuanbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('环比','售水量')][:34])
    zaicehuanbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('环比','在册产销差')][:34])
    zonghehuanbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('环比','综合产销差')][:34])

    gongshuiliangleiji = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计','供水量')][:34])
    zaiceshuiliangleiji = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计','在册售水量')][:34])
    shoushuiliangleiji = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计','售水量')][:34])
    zaiceleiji = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计','在册产销差')][:34])
    zongheleiji = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计','综合产销差')][:34])

    gongshuiliangleijitongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计同比','供水量')][:34])
    zaiceshuiliangleijitongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计同比','在册售水量')][:34])
    shoushuiliangleijitongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计同比','售水量')][:34])
    zaiceleijitongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计同比','在册产销差')][:34])
    zongheleijitongbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计同比','综合产销差')][:34])


    zaiceleijihuanbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计环比','在册产销差')][:34])
    zongheleijihuanbi = list(chanxiaocha[chanxiaocha[('月份','月份')]==yue][('累计环比','综合产销差')][:34])    
    
    c = BMap(init_opts=opts.InitOpts(width="1200px", height="800px")
            ).add_schema(
            baidu_ak="EoDE9x4kPxLNCtUMxfGEYlvG9inVGaUr",
            center=[113.398609,23.174159],
            zoom=12,
            is_roam=True,#是否支持缩放

        ).set_global_opts(
            title_opts=opts.TitleOpts(
                title="二级分区累计综合产销差率同比变化热力图",
                #subtitle="data from PM25.in",
                #subtitle_link="http://www.pm25.in",
                pos_left="center",
                title_textstyle_opts=opts.TextStyleOpts(color="#000"),
            ),
    #         toolbox_opts=opts.ToolboxOpts(
    #                      feature = opts.ToolBoxFeatureOpts(
    #                      save_as_image = opts.ToolBoxFeatureSaveAsImageOpts('jpeg'),),
    #                      ),
            visualmap_opts=opts.VisualMapOpts(min_= -50,max_= 50,
                                              pos_right= '0px',pos_top= '5%',
                                              range_color=["lightskyblue","grey", "orangered"],
                                              is_piecewise =True,
                                              pieces = [{"min": 50, "color": '#E64A19'},                                                 
                                                        {"min": 30, "max": 50, "color": '#FF5722'},
                                                        {"min": 10, "max": 30, "color": '#FF8A65'},
                                                        {"min": 0, "max": 10, "color": '#FFCCBC'},
                                                        {"min": -10, "max": 0, "color": '#B3E5FC'},
                                                        {"min": -30, "max": -10, "color": '#4FC3F7'},
                                                        {"min": -50, "max": -30, "color": '#03A9F4'},
                                                        {"max": -50, "color": '#0288D1'}
                                                        ] ,
                                              precision=0,
                                              series_index=1,
                                              dimension = 10,#设置哪个指标显示热力图
                                              range_text = ['综合产销差同比高', '综合产销差同比低'],
                                              textstyle_opts = opts.TextStyleOpts(color = "#B71C1C",font_weight='bolder')
                                             ),
            legend_opts=opts.LegendOpts(is_show=False),
            tooltip_opts=opts.TooltipOpts(trigger="item",formatter=JsCode(  
                                                    """function(params) {
                                                     str = params.data.name+'<br/>'
    +'累计在册产销差：'+ (params.data.value[8]*100).toFixed(2)+'%；同比：'+params.data.value[28].toFixed(2)+'%；环比：'+params.data.value[11].toFixed(2)+'%<br/>'
    +'累计综合产销差：'+ (params.data.value[9]*100).toFixed(2)+'%；同比：'+params.data.value[10].toFixed(2)+'%；环比：'+params.data.value[12].toFixed(2)+'%<br/>'
    +'当月在册产销差：'+(params.data.value[2]*100).toFixed(2)+'%；同比：'+params.data.value[4].toFixed(2)+'%；环比：'+params.data.value[6].toFixed(2)+'%<br/>'
    +'当月综合产销差：'+ (params.data.value[3]*100).toFixed(2)+'%；同比：'+params.data.value[5].toFixed(2)+'%；环比：'+params.data.value[7].toFixed(2)+'%<br/>'
    +'当月供水量：  '+ (params.data.value[13]).toFixed(0)+'万；同比：'+params.data.value[14].toFixed(2)+'%；环比：'+params.data.value[15].toFixed(2)+'%<br/>'
    +'当月在册水量：'+ (params.data.value[16]).toFixed(0)+'万；同比：'+params.data.value[17].toFixed(2)+'%；环比：'+params.data.value[18].toFixed(2)+'%<br/>'
    +'当月售水量：  '+ (params.data.value[19]).toFixed(0)+'万；同比：'+params.data.value[20].toFixed(2)+'%；环比：'+params.data.value[21].toFixed(2)+'%<br/>'
    +'累计供水量：  '+ (params.data.value[22]).toFixed(0)+'万；同比：'+params.data.value[23].toFixed(2)+'%<br/>'
    +'累计在册水量：'+ (params.data.value[24]).toFixed(0)+'万；同比：'+params.data.value[25].toFixed(2)+'%<br/>'
    +'累计售水量：  '+ (params.data.value[26]).toFixed(0)+'万；同比：'+params.data.value[27].toFixed(2)+'%<br/>';
                                                     return str }
                                                """ )
                                         ,textstyle_opts = opts.TextStyleOpts(font_size=14)),
        ).add_control_panel(
            copyright_control_opts=opts.BMapCopyrightTypeOpts(position=2, copyright_= "",offset_height = 100,),
            maptype_control_opts=opts.BMapTypeControlOpts(
                type_=BMapType.MAPTYPE_CONTROL_DROPDOWN
            ),
            scale_control_opts=opts.BMapScaleControlOpts(),
            overview_map_opts=opts.BMapOverviewMapControlOpts(is_open=False),
            navigation_control_opts=opts.BMapNavigationControlOpts(is_enable_geo_location= False),
            geo_location_control_opts=opts.BMapGeoLocationControlOpts(),
        )

    #增加一级分区数据项
    data_zone1= []
    for i in conf_zone1.sections():
        #c.add_coordinate(i[0],i[1],i[2])
        loc = conf_zone1.get(i,"loc")
        loc = [[float(y[0])+0.0065,float(y[1])+0.0059] for y in [x.split(' ') for x in loc.split(',')]]
        loc0 = loc[0]
        loc.append(loc0)
        data_zone1.append(loc)

    #增加二级分区中心点和数据项
    data_zone2= []
    """
    当月在册j1 同比j3 环比j5
    当月综合j2 同比j4 环比j6
    累计在册j7 同比j9 环比j11
    累计综合j8 同比j10 环比j12
    当月供水j13  同比j14 环比j15
    当月在册售水j16  同比j17 环比j18
    当月售水j19,同比j20,环比j21
    累计供水j22,同比j23
    累计在册售水j24,j25,
    累计售水量j26,j27
    """
    for i,j1,j2,j3,j4,j5,j6,j7,j8,j9,j10,j11,j12,j13,j14,j15,j16,j17,j18,j19,j20,j21,j22,j23,j24,j25,j26,j27 in zip(
        res_zone2,zaice,zonghe,zaicetongbi,zonghetongbi,zaicehuanbi,zonghehuanbi,
        zaiceleiji,zongheleiji,zaiceleijitongbi,zongheleijitongbi,zaiceleijihuanbi,zongheleijihuanbi,
        gongshuiliang,gongshuiliangtongbi,gongshuilianghuanbi,
        zaiceshuiliang,zaiceshuiliangtongbi,zaiceshuilianghuanbi,
        shoushuiliang,shoushuiliangtongbi,shoushuilianghuanbi,
        gongshuiliangleiji,gongshuiliangleijitongbi,
        zaiceshuiliangleiji,zaiceshuiliangleijitongbi,
        shoushuiliangleiji,shoushuiliangleijitongbi):
        c.add_coordinate(i[0],i[1],i[2])
        loc = conf_zone2.get(i[0],"loc")
        loc = [[float(y[0])+0.0065,float(y[1])+0.0059] for y in [x.split(' ') for x in loc.split(',')]]
        data_zone2.append(opts.MapItem(name=i[0],value=[re.findall(r"^\S+\d+",i[0])[0],str(loc),j1,j2,j3,j4,j5,j6,j7,j8,j10,j11,j12,j13,j14,j15,j16,j17,j18,j19,j20,j21,j22,j23,j24,j25,j26,j27,j9]))

    #增加三级分区数据项
    data_zone3= []
    for i in conf_zone3.sections():
        #c.add_coordinate(i[0],i[1],i[2])
        loc = conf_zone3.get(i,"loc")
        loc = [[float(y[0])+0.0065,float(y[1])+0.0059] for y in [x.split(' ') for x in loc.split(',')]]
        data_zone3.append(opts.MapItem(name=i,value=[re.findall(r"(?<=\)).+$",i)[0],str(loc),0]))

    #增加热力图
    # c.add(  "产销差率",
    #         data_zone2,
    #         type_="heatmap",
    #         label_opts=opts.LabelOpts(formatter="{b}"),
    #     )

    #增加水厂点
    data = []
    for i in res_shuichang:
        c.add_coordinate(i[0],i[1][0],i[1][1])
        data.append([i[0],i[2]])

    #画水厂
    c.add(type_="effectScatter",
            series_name="水厂",
            data_pair=data,
            symbol_size=8,
            effect_opts=opts.EffectOpts(),
            label_opts=opts.LabelOpts(formatter="{b}", position="right", is_show=True),
            itemstyle_opts=opts.ItemStyleOpts(color="purple"),)

    #画二级分区
    c.add(series_name='二级分区',       
        type_=ChartType.CUSTOM,
        render_item=JsCode("""
        function renderItem(params, api) {
            var coords = eval(api.value(1));
            var points = [];
            for (var i = 0; i < coords.length; i++) {
                points.push(api.coord(coords[i]));
            }
            var color = api.visual('color');

            return {
                type: 'polygon',
                shape: {
                    points: new echarts.graphic.clipPointsByRect(points, {
                        x: params.coordSys.x,
                        y: params.coordSys.y,
                        width: params.coordSys.width,
                        height: params.coordSys.height
                    })
                },
                style: api.style({
                    fill: color,
                    z: 2,            
                    opacity:0.6,                
                    lineWidth: 1,
                    textAlign: 'center',
                    textVerticalAlign:'bottom',
                    stroke: new echarts.color.lift(color)                   
                }),
                styleEmphasis: api.styleEmphasis()
            };
        }

            """),        
        data_pair = data_zone2
         )

    #画一级分区
    c.add(series_name='一级分区',
          type_="lines",
          data_pair = data_zone1,
          is_polyline=True,       
          linestyle_opts=opts.LineStyleOpts(color="#fff", opacity=1, width=2,type_='dashed'),
          effect_opts=opts.EffectOpts(is_show = False),       
         )
    tl_leijizonghe.add(c, "{}".format(yue))
#tl.render("二级分区累计在册产销差月度变化.html")

# %%
tab = Tab()
tab.add(tl_leijizaice, "累计在册产销差")
tab.add(tl_leijizonghe, "累计综合产销差")

tab.render("二级分区产销差月度变化.html")
# Out:
#   [113.2887354548, 23.164821370800002],
#   [113.28919061189997, 23.1643766177],
#   [113.289521948, 23.163947192400002],
#   [113.29006229230002, 23.1630164115],
#   [113.29067664020003, 23.1619695913],
#   [113.29128605620001, 23.161496738],
#   [113.2923433706, 23.160737807300002],
#   [113.29346793410001, 23.1603402814],
#   [113.29445199770002, 23.1601774928],
#   [113.2951041525, 23.160158955100002],
#   [113.29542431520001, 23.1601941911],
#   [113.29779246319997, 23.160574555100002],
#   [113.2981104707, 23.1605734707],
#   [113.29918165669999, 23.160573308300002],
#   [113.3012844826, 23.160150756300002],
#   [113.30176607330002, 23.1615477528],
#   [113.29884683059997, 23.1615983238],
#   [113.2978092042, 23.161613505200002],
#   [113.29495732080004, 23.1622962845],
#   [113.29328378429999, 23.162677642000002],
#   [113.29139613160002, 23.1631299348],
#   [113.29084051300002, 23.1643568322],
#   [113.29062964159998, 23.1649007887],
#   [113.29221934260003, 23.165926099900002],
#   [113.29437815959999, 23.1673232156],
#   [113.29421748970002, 23.1675054465],
#   [113.29234304449999, 23.1694882618],
#   [113.29080671270002, 23.171100504],
#   [113.28949467170001, 23.1724780593],
#   [113.28841694449999, 23.1736240106],
#   [113.28783330870003, 23.174219789000002],
#   [113.28774524499998, 23.1742397233],
#   [113.28829070880003, 23.1766187811],
#   [113.28897643750001, 23.1794813047],
#   [113.29228916219999, 23.1788874852],
#   [113.29357814350003, 23.1808419865],
#   [113.29526762660002, 23.1833878743],
#   [113.2971135353, 23.1861820935],
#   [113.29862750850002, 23.1884572622],
#   [113.29998041719999, 23.1905022336],
#   [113.3008216736, 23.191631198],
#   [113.3013894365, 23.1928596871],
#   [113.30232310770002, 23.194757551000002],
#   [113.30336354299997, 23.196849107400002],
#   [113.3044459645, 23.199025190100002],
#   [113.30542934489999, 23.2009865091],
#   [113.30580289290002, 23.2017330109],
#   [113.30576104150002, 23.203080582200002],
#   [113.3057306562, 23.2050580015],
#   [113.30564607670003, 23.2065152619],
#   [113.30778225379997, 23.206539932200002],
#   [113.312403763, 23.2066104674],
#   [113.31719504369998, 23.2066689058],
#   [113.31630758620001, 23.2093706532],
#   [113.31547957880001, 23.211903549],
#   [113.31458750840004, 23.2146728733],
#   [113.31374116019997, 23.2172690998],
#   [113.31729374900003, 23.2181658525],
#   [113.31836471579997, 23.2184310856],
#   [113.32169949509999, 23.219261847200002],
#   [113.32419254699998, 23.2172308207],
#   [113.3236902067, 23.2189896569],
#   [113.32335671259999, 23.220143603300002],
#   [113.32303595299997, 23.2212839394],
#   [113.32258037749999, 23.2228534702],
#   [113.32197566270001, 23.2249444451],
#   [113.32265726439998, 23.2270363951],
#   [113.3230967878, 23.228294233],
#   [113.3235829394, 23.2296836396],
#   [113.32427774649999, 23.2316653547],
#   [113.32473925729998, 23.2329771243],
#   [113.32549132809997, 23.2351094483],
#   [113.32583910480001, 23.2360942142],
#   [113.32650854289999, 23.2379881092],
#   [113.32825334919998, 23.238394569100002],
#   [113.33119278150001, 23.2390960134],
#   [113.33198738959997, 23.239286648900002],
#   [113.3354554241, 23.240113562],
#   [113.33615665500001, 23.240279151],
#   [113.33725207820002, 23.2405362103],
#   [113.3396771563, 23.2423877419],
#   [113.342476292, 23.2445173956],
#   [113.34303488279998, 23.2449421202],
#   [113.34740240910001, 23.2482663181],
#   [113.3506480002, 23.250729475300002],
#   [113.35202412099999, 23.2517707512],
#   [113.3533890254, 23.2527998327],
#   [113.35503461349997, 23.2540377903],
#   [113.35627684109998, 23.2549734408],
#   [113.35750814320004, 23.2559017809],
#   [113.35862132560003, 23.2573858405],
#   [113.35908836700001, 23.2580083743],
#   [113.3609281536, 23.2604565321],
#   [113.36161094610001, 23.2613610658],
#   [113.36269476390002, 23.2627909559],
#   [113.36375407109999, 23.2641884807],
#   [113.3650977048, 23.265973339200002],
#   [113.36504744969999, 23.2666108272],
#   [113.36456480489998, 23.2677194301],
#   [113.36426175659999, 23.2684446982],
#   [113.36359366230003, 23.2695219402],
#   [113.36261642280003, 23.270396598],
#   [113.36196480030002, 23.2707378],
#   [113.36091999440002, 23.2714205393],
#   [113.36032458409998, 23.271875829],
#   [113.3595043929, 23.272325605],
#   [113.35908878960002, 23.2728174198],
#   [113.35870137290003, 23.2735321551],
#   [113.35865673840003, 23.2742681201],
#   [113.3589155198, 23.2749371434],
#   [113.3598208838, 23.276426059800002],
#   [113.3615304227, 23.2792741096],
#   [113.36264953480001, 23.2812038397],
#   [113.36296476199998, 23.2823912406],
#   [113.36386502629999, 23.2849322575],
#   [113.36747932220003, 23.2875078358],
#   [113.36840687530001, 23.2884004997],
#   [113.36873291279998, 23.2886963416],
#   [113.36953152070002, 23.290164158],
#   [113.36964452300002, 23.2913875345],
#   [113.36999924210004, 23.2928237066],
#   [113.37017445420001, 23.294819450000002],
#   [113.37049641740002, 23.2980800566],
#   [113.37084045300001, 23.300547650400002],
#   [113.37147118789999, 23.3032488019],
#   [113.37213575930001, 23.3061572985],
#   [113.36727034189998, 23.308038176100002],
#   [113.3642754516, 23.3091953099],
#   [113.36240426350001, 23.310011698100002],
#   [113.36063414020002, 23.3107918652],
#   [113.35919494670001, 23.311161047],
#   [113.35785461150003, 23.3116433173],
#   [113.3544405338, 23.3127122716],
#   [113.35031203890001, 23.3139841295],
#   [113.34734058709999, 23.314901967],
#   [113.34647357409999, 23.3151681796],
#   [113.34365110679998, 23.3165263444],
#   [113.34081136159999, 23.3179002514],
#   [113.33755130429999, 23.3191606752],
#   [113.33501883860002, 23.3200930416],
#   [113.33168802469997, 23.3212875351],
#   [113.3275474398, 23.3227922841],
#   [113.32371725760002, 23.3221940117],
#   [113.32253028350003, 23.3202761852],
#   [113.32173050980002, 23.3189976216],
#   [113.3209510135, 23.3169114576],
#   [113.31919391180001, 23.3157533678],
#   [113.31832812219999, 23.3151790503],
#   [113.31637252789999, 23.3138798066],
#   [113.31379578789999, 23.3121522926],
#   [113.30927428099999, 23.3097409373],
#   [113.30807149529998, 23.309098900200002],
#   [113.31191642769998, 23.3145589562],
#   [113.31191642769998, 23.3145589562]]]
